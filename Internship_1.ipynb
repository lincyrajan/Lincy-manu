# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/credit.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27330 entries, 0 to 27329
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        27330 non-null  int64
#  1   Customer_ID               27329 non-null  float64
#  2   Month                     27329 non-null  float64
#  3   Name                      27329 non-null  object
#  4   Age                       27329 non-null  float64
#  5   SSN                       27329 non-null  float64
#  6   Occupation                27329 non-null  object
#  7   Annual_Income             27329 non-null  float64
#  8   Monthly_Inhand_Salary     27329 non-null  float64
#  9   Num_Bank_Accounts         27329 non-null  float64
#  10  Num_Credit_Card           27329 non-null  float64
#  11  Interest_Rate             27329 non-null  float64
#  12  Num_of_Loan               27329 non-null  float64
# ...

# %%
df.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634       3392.0    1.0  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635       3392.0    2.0  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636       3392.0    3.0  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637       3392.0    4.0  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638       3392.0    5.0  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %%
df.shape
# Out:
# (27330, 28)

# %%
# Check for null values
df.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 1
# Month                       1
# Name                        1
# Age                         1
# SSN                         1
# Occupation                  1
# Annual_Income               1
# Monthly_Inhand_Salary       1
# Num_Bank_Accounts           1
# Num_Credit_Card             1
# Interest_Rate               1
# Num_of_Loan                 1
# Type_of_Loan                1
# Delay_from_due_date         1
# Num_of_Delayed_Payment      1
# Changed_Credit_Limit        1
# Num_Credit_Inquiries        1
# Credit_Mix                  1
# Outstanding_Debt            1
# Credit_Utilization_Ratio    1
# Credit_History_Age          1
# Payment_of_Min_Amount       1
# Total_EMI_per_month         1
# Amount_invested_monthly     1
# Payment_Behaviour           1
# Monthly_Balance             1
# Credit_Score                1
# dtype: int64

# %%
df.fillna(method ='pad')
# Out:
#           ID  Customer_ID  Month                   Name   Age          SSN  \
# 0       5634       3392.0    1.0          Aaron Maashoh  23.0  821000265.0
# 1       5635       3392.0    2.0          Aaron Maashoh  23.0  821000265.0
# 2       5636       3392.0    3.0          Aaron Maashoh  23.0  821000265.0
# 3       5637       3392.0    4.0          Aaron Maashoh  23.0  821000265.0
# 4       5638       3392.0    5.0          Aaron Maashoh  23.0  821000265.0
# ...      ...          ...    ...                    ...   ...          ...
# 27325  46619      36182.0    6.0  George Georgiopoulosv  37.0   63476931.0
# 27326  46620      36182.0    7.0  George Georgiopoulosv  37.0   63476931.0
# 27327  46621      36182.0    8.0  George Georgiopoulosv  37.0   63476931.0
# 27328  46626      28227.0    1.0      Alexei Oreskovicl  45.0  409830158.0
# 27329  46627      28227.0    1.0      Alexei Oreskovicl  45.0  409830158.0
#
# ...

# %%
df.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 1
# Month                       1
# Name                        1
# Age                         1
# SSN                         1
# Occupation                  1
# Annual_Income               1
# Monthly_Inhand_Salary       1
# Num_Bank_Accounts           1
# Num_Credit_Card             1
# Interest_Rate               1
# Num_of_Loan                 1
# Type_of_Loan                1
# Delay_from_due_date         1
# Num_of_Delayed_Payment      1
# Changed_Credit_Limit        1
# Num_Credit_Inquiries        1
# Credit_Mix                  1
# Outstanding_Debt            1
# Credit_Utilization_Ratio    1
# Credit_History_Age          1
# Payment_of_Min_Amount       1
# Total_EMI_per_month         1
# Amount_invested_monthly     1
# Payment_Behaviour           1
# Monthly_Balance             1
# Credit_Score                1
# dtype: int64

# %%
df.drop('ID',axis=1,inplace=True)
df.head(5)
# Out:
#    Customer_ID  Month           Name   Age          SSN Occupation  \
# 0       3392.0    1.0  Aaron Maashoh  23.0  821000265.0  Scientist
# 1       3392.0    2.0  Aaron Maashoh  23.0  821000265.0  Scientist
# 2       3392.0    3.0  Aaron Maashoh  23.0  821000265.0  Scientist
# 3       3392.0    4.0  Aaron Maashoh  23.0  821000265.0  Scientist
# 4       3392.0    5.0  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       19114.12            1824.843333                3.0              4.0
# 1       19114.12            1824.843333                3.0              4.0
# 2       19114.12            1824.843333                3.0              4.0
# 3       19114.12            1824.843333                3.0              4.0
# 4       19114.12            1824.843333                3.0              4.0
#
#    ...  Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
# ...

# %%
df.fillna(df.select_dtypes(include='number').median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer_ID                 0
# Month                       0
# Name                        1
# Age                         0
# SSN                         0
# Occupation                  1
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                1
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  1
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       1
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           1
# Monthly_Balance             0
# Credit_Score                1
# dtype: int64

# %%
df.describe()
# Out:
#         Customer_ID         Month           Age           SSN  Annual_Income  \
# count  27330.000000  27330.000000  27330.000000  2.733000e+04   27330.000000
# mean   25899.944530      4.499854     33.252689  4.928836e+08   51245.745246
# std    14439.378334      2.291346     10.671194  2.932000e+08   38708.526627
# min     1006.000000      1.000000     14.000000  6.304420e+05    7006.520000
# 25%    13851.000000      2.250000     25.000000  2.334661e+08   19599.810000
# 50%    25457.000000      4.000000     33.000000  4.821045e+08   37464.040000
# 75%    38617.000000      6.000000     42.000000  7.477979e+08   73134.060000
# max    50984.000000      8.000000     56.000000  9.999573e+08  179987.280000
#
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           27330.000000       27330.000000     27330.000000
# mean             4256.148588           5.336443         5.526564
# std              3210.256904           2.618688         2.053683
# ...

# %%
## to know duplicates

df[df.duplicated(keep='first')]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 27 columns]

# %%
# Outlier Analysis
fig, axs = plt.subplots(3, figsize = (5,5))
plt1 = sns.boxplot(x=df['Annual_Income'], ax = axs[0],color='r')
plt2 = sns.boxplot(x=df['Credit_History_Age'],ax = axs[1], color='b')
plt3 = sns.boxplot(x=df['Credit_Score'], ax = axs[2],color='g')
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-255c83729cbe> in <cell line: 2>()
#       1 plt.figure(figsize=(20,10))
# ----> 2 c= df.corr()
#       3 sns.heatmap(c,cmap="BrBG",annot=True)
#       4 c
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
# ...

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
X = pd.get_dummies(x, drop_first=True)
print(X)
# Splitting data into training and test set:
X_train,X_test, y_train, y_test =train_test_split(X,y, test_size=0.3, random_state=25,stratify=y)
print(X_train.shape,X_test.shape)

# %%
# iloc[ror]

X=df.iloc[:,:].values

y=df['Credit_Score']

# %%
# training : 80% & testing: 20%

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC


# Create and train a Support Vector Classifier (SVC)
svc_classifier = SVC()
svc_classifier.fit(X_train, y_train)

# Create and train a K-Nearest Neighbors Classifier (KNN)
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train, y_train)

# %%
# Fitting K-NN to the Training set
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)

# %%
df.head(5)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Name'] = le.fit_transform(df['Name'])
df['Occupation'] = le.fit_transform(df['Occupation'])
df['Credit_Mix'] = le.fit_transform(df['Credit_Mix'])
df['Payment_of_Min_Amount'] = le.fit_transform(df['Payment_of_Min_Amount'])
df['Payment_Behaviour'] = le.fit_transform(df['Payment_Behaviour'])
df['Credit_Score'] = le.fit_transform(df['Credit_Score'])

# %%
# iloc[ror]

X=df.iloc[:,:-1].values

y=df['Credit_Score']

# %%
# training : 80% & testing: 20%

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
for column in df.columns:
    if df[column].dtype != float and df[column].dtype != int:
        print(f"Column '{column}' has non-numeric values.")

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming 'Type_of_Loan' is the column causing the error
le = LabelEncoder()
df['Type_of_Loan'] = le.fit_transform(df['Type_of_Loan'])

# %%
# Convert 'Name' column to string type
df['Type_of_Loan'] = df['Type_of_Loan'].astype(str)

# Replace the problematic value with a more suitable representation
df['Type_of_Loan'] = df['Type_of_Loan'].str.replace('Payday Loan, Credit-Builder Loan,Auto Loan', 'Other')

# Continue with the LabelEncoder
le = LabelEncoder()
df['Name'] = le.fit_transform(df['Name'])

# %%
# Convert 'Amount' column to float, replacing errors with NaN
df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')

# Fill NaN values with 0
df['Amount'] = df['Amount'].fillna(0)

# Now, you can proceed with the calculations
mean_amount = df['Amount'].mean()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC


# Create and train a Support Vector Classifier (SVC)
svc_classifier = SVC()
svc_classifier.fit(X_train, y_train)

# Create and train a K-Nearest Neighbors Classifier (KNN)
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train, y_train)
